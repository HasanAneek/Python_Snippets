# %%
import pandas as pd

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId', na_values = na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col="qname")

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
filt = (df['Country'] == 'Bangladesh')
BD_df = df.loc[filt]
BD_df.head()
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 40          I agree                     I am a developer by profession
# 208         I agree                     I am a developer by profession
# 256         I agree  I am not primarily a developer, but I write co...
# 275         I agree                     I am a developer by profession
# 380         I agree                     I am a developer by profession
#
#                         Age           Employment  \
# ResponseId
# 40          25-34 years old  Employed, full-time
# 208         25-34 years old  Employed, part-time
# 256         18-24 years old   Student, full-time
# 275         25-34 years old  Employed, full-time
# 380         25-34 years old  Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 40          Hybrid (some remote, some in-person)
# 208                                       Remote
# 256                                          NaN
# ...

# %%
BD_df.to_csv('data/updated.csv')

# %%
BD_df.to_csv('data/update.tsv', sep='\t')

# %%
BD_df.to_excel('data/updated.xlsx')

# %%
test = pd.read_excel('data/updated.xlsx', index_col="ResponseId")
test
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 40          I agree                     I am a developer by profession
# 208         I agree                     I am a developer by profession
# 256         I agree  I am not primarily a developer, but I write co...
# 275         I agree                     I am a developer by profession
# 380         I agree                     I am a developer by profession
# ...             ...                                                ...
# 87942       I agree                     I am a developer by profession
# 88146       I agree                        I code primarily as a hobby
# 88935       I agree                     I am a developer by profession
# 89034       I agree                     I am a developer by profession
# 89125       I agree                     I am a developer by profession
#
#                            Age  \
# ResponseId
# 40             25-34 years old
# ...

# %%
BD_df.to_json('data/updated.json')

# %%
BD_df.to_json('data/new.json', orient='records', lines=True)

# %%
Demo = pd.read_json('data/new.json', orient='records', lines=True)
Demo.head()
# Out:
#       Q120                                         MainBranch  \
# 0  I agree                     I am a developer by profession
# 1  I agree                     I am a developer by profession
# 2  I agree  I am not primarily a developer, but I write co...
# 3  I agree                     I am a developer by profession
# 4  I agree                     I am a developer by profession
#
#                Age           Employment                            RemoteWork  \
# 0  25-34 years old  Employed, full-time  Hybrid (some remote, some in-person)
# 1  25-34 years old  Employed, part-time                                Remote
# 2  18-24 years old   Student, full-time                                  None
# 3  25-34 years old  Employed, full-time  Hybrid (some remote, some in-person)
# 4  25-34 years old  Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# 0  Hobby;Contribute to open-source projects;Profe...
# ...

# %%
import sqlite3

# %%
connection = sqlite3.connect('OurDB.db')

# %%
cursor = connection.cursor()

# %%
cursor.execute('CREATE TABLE employees(name TEXT, surname TEXT, salary REAL)')

# %%
connection.commit()
