# %%
import pandas as pd

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv',index_col='ResponseId', na_values = na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv',index_col='qname')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# Q310                  QID310
# Q120                  QID312
# S1                      QID1
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# TechList              QID322
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# ...

# %%
schema_df.sort_index(inplace=True)

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df.rename(columns={'CompTotal':'SalaryUSD'},inplace=True)

# %%
df['SOAccount'] = df['SOAccount'].map({'Yes':True,'No':False})

# %%
df.sort_values(by=['Country','SalaryUSD'],ascending=(True,False),inplace=True)

# %%
df.nlargest(10,'SalaryUSD')
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 56323       I agree                     I am a developer by profession
# 18464       I agree                     I am a developer by profession
# 43557       I agree                     I am a developer by profession
# 49554       I agree  I am not primarily a developer, but I write co...
# 35780       I agree                     I am a developer by profession
# 15440       I agree                     I am a developer by profession
# 33079       I agree                     I am a developer by profession
# 19680       I agree                     I am a developer by profession
# 56854       I agree  I am not primarily a developer, but I write co...
# 9176        I agree                     I am a developer by profession
#
#                         Age  \
# ResponseId
# 56323       25-34 years old
# 18464       25-34 years old
# 43557       18-24 years old
# 49554       25-34 years old
# ...

# %%
df['SalaryUSD'].head(15)
# Out:
# ResponseId
# 88348    932464379.0
# 1335        210000.0
# 57362       200000.0
# 17873       100000.0
# 36049        80000.0
# 53322        69420.0
# 86039        68000.0
# 41679        56666.0
# 39427         4200.0
# 37956         3600.0
# 2642           123.0
# 61076            1.0
# 59006            0.0
# 67794            0.0
# 2301             NaN
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median()
# Out:
# 115000.0

# %%
df['LearnCodeCoursesCert']
# Out:
# ResponseId
# 88348               NaN
# 1335     Udemy;Coursera
# 57362               NaN
# 17873               NaN
# 36049        Codecademy
#               ...
# 88821               NaN
# 88829               NaN
# 88831               NaN
# 89029               NaN
# 89160               NaN
# Name: LearnCodeCoursesCert, Length: 89184, dtype: object

# %%
schema_df.loc['LearnCodeCoursesCert']
# Out:
# qid                                                      QID306
# question      What online courses or certifications do you u...
# force_resp                                                False
# type                                                         MC
# selector                                                   MAVR
# Name: LearnCodeCoursesCert, dtype: object

# %%
df['LearnCodeCoursesCert'].value_counts()
# Out:
# LearnCodeCoursesCert
# Udemy                                                    7445
# Other                                                    3230
# Udemy;Coursera                                           2612
# Udemy;Pluralsight                                        1958
# Codecademy;Udemy                                         1837
#                                                          ...
# Other;Codecademy;Udemy;Pluralsight;Coursera;Skillsoft       1
# Other;edX;Skillsoft                                         1
# Other;Udemy;Coursera;Udacity;Skillsoft                      1
# Other;Udemy;Pluralsight;Coursera;Udacity;Skillsoft          1
# Other;Codecademy;edX;Pluralsight;Coursera;Skillsoft         1
# Name: count, Length: 210, dtype: int64

# %%
df['LearnCodeCoursesCert'].value_counts(normalize=True)
# Out:
# LearnCodeCoursesCert
# Udemy                                                    0.200804
# Other                                                    0.087118
# Udemy;Coursera                                           0.070450
# Udemy;Pluralsight                                        0.052810
# Codecademy;Udemy                                         0.049547
#                                                            ...
# Other;Codecademy;Udemy;Pluralsight;Coursera;Skillsoft    0.000027
# Other;edX;Skillsoft                                      0.000027
# Other;Udemy;Coursera;Udacity;Skillsoft                   0.000027
# Other;Udemy;Pluralsight;Coursera;Udacity;Skillsoft       0.000027
# Other;Codecademy;edX;Pluralsight;Coursera;Skillsoft      0.000027
# Name: proportion, Length: 210, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Grenada                                                     1
# Guinea-Bissau                                               1
# Liechtenstein                                               1
# Marshall Islands                                            1
# Saint Kitts and Nevis                                       1
# Name: count, Length: 185, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States of America')
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 49554       I agree  I am not primarily a developer, but I write co...
# 66758       I agree                     I am a developer by profession
# 80587       I agree                     I am a developer by profession
# 771         I agree                     I am a developer by profession
# 88904       I agree                     I am a developer by profession
# ...             ...                                                ...
# 89088       I agree                     I am a developer by profession
# 89119       I agree                     I am a developer by profession
# 89135       I agree                        I code primarily as a hobby
# 89148       I agree                              I am learning to code
# 89151       I agree  I used to be a developer by profession, but no...
#
#                            Age  \
# ResponseId
# 49554          25-34 years old
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LearnCodeCoursesCert'].value_counts()
# Out:
# LearnCodeCoursesCert
# Udemy                                                814
# Udemy;Coursera                                       463
# Other                                                229
# Udemy;Pluralsight                                    158
# Coursera                                             137
#                                                     ...
# Other;Udemy;Skillsoft                                  1
# Codecademy;Pluralsight;Skillsoft                       1
# Codecademy;edX;Pluralsight;Coursera;Udacity            1
# Other;Codecademy;Udemy;Coursera;Udacity;Skillsoft      1
# Codecademy;Udemy;Coursera;Udacity;Skillsoft            1
# Name: count, Length: 124, dtype: int64

# %%
country_grp['LearnCodeCoursesCert'].value_counts().loc['Bangladesh']
# Out:
# LearnCodeCoursesCert
# Udemy                                                                56
# Other                                                                40
# Udemy;Coursera                                                       34
# Codecademy;Udemy;Coursera                                            19
# Other;Udemy                                                          11
# Udemy;Pluralsight;Coursera                                           10
# Coursera                                                             10
# Udemy;Pluralsight                                                     8
# edX;Udemy;Coursera                                                    8
# Codecademy;Udemy                                                      7
# Other;Codecademy;Udemy                                                5
# Codecademy;edX;Udemy;Coursera                                         5
# Codecademy                                                            5
# ...

# %%
job_type = df.groupby(['LanguageHaveWorkedWith'])

# %%
df['LanguageHaveWorkedWith'].value_counts(normalize=True)
# Out:
# LanguageHaveWorkedWith
# HTML/CSS;JavaScript;TypeScript                                                                    0.017064
# Python                                                                                            0.012991
# HTML/CSS;JavaScript                                                                               0.008435
# HTML/CSS;JavaScript;PHP;SQL                                                                       0.008240
# C#                                                                                                0.007448
#                                                                                                     ...
# Bash/Shell (all shells);Erlang;Go;Groovy;HTML/CSS;Java;JavaScript;PowerShell;Python;TypeScript    0.000011
# Assembly;Bash/Shell (all shells);C;C#;HTML/CSS;Java;JavaScript;PHP;Python;SQL                     0.000011
# ...

# %%
country_grp['SalaryUSD'].median().loc['Bangladesh']
# Out:
# 600000.0

# %%
country_grp['SalaryUSD'].agg(['median','mean']).loc['Bangladesh']
# Out:
# median    6.000000e+05
# mean      1.132790e+08
# Name: Bangladesh, dtype: float64

# %%
filt1 = df['Country'] == 'Bangladesh'

# %%
df.loc[filt1]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 207

# %%
python = df.groupby(['Country'])['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).loc['Bangladesh']

# %%
python.sort_values(by=)
# Out:
#   Cell In[30], line 1
#     python.sort_values(by=)
#                           ^
# SyntaxError: invalid syntax

# %%
country_num = df['Country'].value_counts()
country_num

# %%
country_grp1 = df.groupby(['Country'])

# %%
country_grp1.get_group('Bangladesh')

# %%
country_python = country_grp1['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_python

# %%
python_df = pd.concat([country_num, country_python],axis='columns')
python_df

# %%
python_df.rename(columns={'count':'Number','LanguageHaveWorkedWith':'Python'},inplace=True)

# %%
python_df

# %%
python_df['pct_python'] = (python_df['Python'] / python_df['Number']) * 100
python_df

# %%
python_df.sort_values(by='pct_python', ascending=False,inplace=True)

# %%
python_df.head(50)

# %%
df['YearsCode'].unique()

# %%
df['YearsCode'] = df['YearsCode'].replace('Less than 1 year','0')

# %%
df['YearsCode'] = df['YearsCode'].replace('More than 50 years','51')

# %%
df['YearsCode'].unique()

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()

# %%
filts = (df['Country'] == 'Bangladesh')
Ban_df = df.loc[filts]
Ban_df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 9176        I agree  I am a developer by profession  25-34 years old
# 22914       I agree  I am a developer by profession  18-24 years old
# 10649       I agree  I am a developer by profession  25-34 years old
# 21179       I agree  I am a developer by profession  25-34 years old
# 3609        I agree  I am a developer by profession  25-34 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# 9176        Employed, full-time                                Remote
# 22914       Employed, part-time                                Remote
# 10649       Employed, full-time                                Remote
# 21179       Employed, full-time                             In-person
# 3609        Employed, full-time  Hybrid (some remote, some in-person)
#
#                                              CodingActivities  \
# ResponseId
# ...

# %%
Ban_df.to_csv('data/updated.csv')

# %%
Ban_df.to_csv('data/updated.tsv', sep="\t")

# %%
Ban_df.to_excel('data/add_new.xlsx',index=False)
